# %% [markdown]
# # Test 3D Visualization in Binder
#
# This notebook tests 2D and 3D mesh visualization with pyGIMLi.

# %%
# Configure PyVista for Jupyter (required for Binder)
import pyvista as pv
pv.set_jupyter_backend('trame')

# %%
import pygimli as pg

# %% [markdown]
# ## 2D Mesh

# %%
n = 10
mesh2d = pg.createGrid(n, n)
pg.show(mesh2d)

# %% [markdown]
# ## 3D Mesh

# %%
mesh3d = pg.createGrid(n, n, n)
pg.show(mesh3d)
